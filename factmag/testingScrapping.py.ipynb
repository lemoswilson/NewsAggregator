# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://www.factmag.com/category/news/")

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="wf-loading" lang="en-US">\n<head>\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />\n    <meta name="google-site-verification" content="rE6HbR3POlv4pCIZCpqc40vKV47gKm6-L4OF_BcDLNo" />\n\n            <meta property="fb:pages" content="52725749686">\n    \n    <title>News Archives - FACT Magazine</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v12.8.1 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"/>\n<link rel="canonical" href="https://www.factmag.com/category/news/" />\n<link rel="next" href="https://www.factmag.com/category/news/page/2/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="object" />\n<meta property="og:title" content="News Archives - FACT Magazine" />\n<meta property="og:url" content="https://www.factmag.com/category/news/"
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="wf-loading" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="rE6HbR3POlv4pCIZCpqc40vKV47gKm6-L4OF_BcDLNo" name="google-site-verification"/>
#   <meta content="52725749686" property="fb:pages"/>
#   <title>
#    News Archives - FACT Magazine
#   </title>
#   <!-- This site is optimized with the Yoast SEO plugin v12.8.1 - https://yoast.com/wordpress/plugins/seo/ -->
#   <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
#    <link href="https://www.factmag.com/category/news/" rel="canonical"/>
#    <link href="https://www.factmag.com/category/news/page/2/" rel="next"/>
#    <meta content="en_US" property="og:locale"/>
#    <meta content="object" property="og:type"/>
#    <meta content="News Archives - FACT Magazine" property="og:title"/>
# ...

# %%
all = soup.find_all("div", {"class": "featured-wrapper"})

# %%
all[0].find_all()
# Out:
# [<div class="featured-wrapper clearfix">
# <div class="col-lg-6 col-md-6 col-sm-12 col-xs-12 col-single">
# <div class="block-post-wrapper row-single">
# <div class="block-post-thumbnail">
# <a class="thumb-permalink standard" href="https://www.factmag.com/2020/01/28/watch-angel-hos-teaser-trailer-for-her-upcoming-new-album/" title="Watch Angel-Ho’s teaser-trailer for her upcoming new album">
# <img alt="Watch Angel-Ho’s teaser-trailer for her upcoming new album" src="https://s3.amazonaws.com/factmag-images/wp-content/uploads/2020/01/81638093_2823280551063622_337394321328177152_n-250x155.jpg" srcset="https://s3.amazonaws.com/factmag-images/wp-content/uploads/2020/01/81638093_2823280551063622_337394321328177152_n-250x155.jpg 1x, https://s3.amazonaws.com/factmag-images/wp-content/uploads/2020/01/81638093_2823280551063622_337394321328177152_n-500x310.jpg 2x"/>
# <span class="overlay-hover"></span>
# </a>
# </div>
# ...

# %%
all[0].find_all("a")[0].title

# %%
print(all[0].find_all("a")[0].title)
# Out:
# None

# %%
a1 = all[0].find_all("a", {"class": "thumb-permalink"})

# %%
a1[0]
# Out:
# <a class="thumb-permalink standard" href="https://www.factmag.com/2020/01/28/watch-angel-hos-teaser-trailer-for-her-upcoming-new-album/" title="Watch Angel-Ho’s teaser-trailer for her upcoming new album">
# <img alt="Watch Angel-Ho’s teaser-trailer for her upcoming new album" src="https://s3.amazonaws.com/factmag-images/wp-content/uploads/2020/01/81638093_2823280551063622_337394321328177152_n-250x155.jpg" srcset="https://s3.amazonaws.com/factmag-images/wp-content/uploads/2020/01/81638093_2823280551063622_337394321328177152_n-250x155.jpg 1x, https://s3.amazonaws.com/factmag-images/wp-content/uploads/2020/01/81638093_2823280551063622_337394321328177152_n-500x310.jpg 2x"/>
# <span class="overlay-hover"></span>
# </a>

# %%
a1[0].get_title()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7a07119a809e> in <module>
# ----> 1 a1[0].get_title()
#
# TypeError: 'NoneType' object is not callable

# %%
type(a1[0])
# Out:
# bs4.element.Tag

# %%
a1[0]['title']
# Out:
# 'Watch Angel-Ho’s teaser-trailer for her upcoming new album'

# %%
a1[0]['href']
# Out:
# 'https://www.factmag.com/2020/01/28/watch-angel-hos-teaser-trailer-for-her-upcoming-new-album/'

# %%
d1 = all[0].find_all("p", {"class": "meta"})

# %%
d1
# Out:
# [<p class="meta"><a href="https://www.factmag.com/category/news/" rel="category tag">News</a> <span>I</span> <span>28.01.20</span></p>,
#  <p class="meta"><a href="https://www.factmag.com/category/news/" rel="category tag">News</a> <span>I</span> <span>28.01.20</span></p>]

# %%
d1 = all[0].find("p", {"class": "meta"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d6a6f2d7c2f8> in <module>
# ----> 1 d1 = all[0].find("p", {"class": "meta"}).find("span")[1].text
#
# /usr/local/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#    1319         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1320         and throws an exception if it's not there."""
# -> 1321         return self.attrs[key]
#    1322
#    1323     def __iter__(self):
#
# KeyError: 1

# %%
d1..find("span")[1].text
# Out:
#   File "<ipython-input-23-96daf5be4c91>", line 1
#     d1..find("span")[1].text
#        ^
# SyntaxError: invalid syntax

# %%
d1.find("span")
# Out:
# <span>I</span>

# %%
d1.find_all("span")[1].text
# Out:
# '28.01.20'

# %%
type(d1.find_all("span")[1].text)
# Out:
# str
